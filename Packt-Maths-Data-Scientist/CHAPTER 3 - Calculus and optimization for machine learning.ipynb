# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.optimize import minimize_scalar

# %%
def func(x):
    return 0.1*x**2+5*np.sin(x)*np.exp(-0.05*x)

# %%
a=np.linspace(-20,20,400)

# %%
y=func(a)

# %%
plt.figure(figsize=(8,4))
plt.plot(a,y,c='k',lw=3)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Variable '+'$x$',fontsize=15)
plt.ylabel('Function '+'$f(x)$',fontsize=15)
plt.ylim(-10,50)
plt.grid(True)

# %%
minx = minimize_scalar(func, bounds=[-20,20],method='Bounded',tol=0.00001)
# Out:
# c:\users\tirtha\python\anaconda3\lib\site-packages\scipy\optimize\_minimize.py:643: RuntimeWarning: Method 'bounded' does not support relative tolerance in x; defaulting to absolute tolerance.
#   "defaulting to absolute tolerance.", RuntimeWarning)

# %%
print(minx)
# Out:
#      fun: -1.8855732605754767
#  message: 'Solution found.'
#     nfev: 12
#   status: 0
#  success: True
#        x: 4.4391618582349075

# %%
minx = minimize_scalar(func, method='Brent',tol=0.001)

# %%
print(minx)
# Out:
#      fun: -5.16196298985529
#     nfev: 7
#      nit: 6
#  success: True
#        x: -1.562985103421072

# %%
minx = minimize_scalar(func,method='Golden',tol=0.001)

# %%
print(minx)
# Out:
#      fun: -5.1619622440932185
#     nfev: 21
#      nit: 15
#  success: True
#        x: -1.563492151319239
